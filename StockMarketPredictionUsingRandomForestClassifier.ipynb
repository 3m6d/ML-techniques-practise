# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import os

# %%
if os.path.exists("sp500.csv"):
    sp500 = pd.read_csv("sp500.csv", index_col=0)
else:
    sp500 = yf.Ticker("^GSPC")
    sp500 = sp500.history(period="max")
    sp500.to_csv("sp500.csv")

# %%
sp500.index = pd.to_datetime(sp500.index, utc=True)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 05:00:00+00:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 05:00:00+00:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 05:00:00+00:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 05:00:00+00:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 05:00:00+00:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-26 04:00:00+00:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 04:00:00+00:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 04:00:00+00:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 04:00:00+00:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 04:00:00+00:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
print(sp500.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
sp500 = sp500.drop(columns=["Dividends", "Stock Splits"])

# %%
print(sp500.columns)
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
#creating new column named Tommorow
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 05:00:00+00:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 05:00:00+00:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 05:00:00+00:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 05:00:00+00:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 05:00:00+00:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-08-26 04:00:00+00:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 04:00:00+00:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 04:00:00+00:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 04:00:00+00:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 04:00:00+00:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
#create a new column called target that gives boolean number as 1 for true or 0 for false if the closing price is greater than tommorow
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
#entries from 1990-01-01 will be copied to sp500
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 05:00:00+00:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 05:00:00+00:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 05:00:00+00:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 05:00:00+00:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 05:00:00+00:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-08-26 04:00:00+00:00  5639.660156  5651.620117  5602.339844  5616.839844
# 2024-08-27 04:00:00+00:00  5602.890137  5631.180176  5593.479980  5625.799805
# 2024-08-28 04:00:00+00:00  5624.509766  5627.029785  5560.950195  5592.180176
# 2024-08-29 04:00:00+00:00  5607.299805  5646.950195  5583.709961  5591.959961
# 2024-08-30 04:00:00+00:00  5612.740234  5651.370117  5581.790039  5648.399902
#
# ...

# %%
#RandomForestClassifer is classification machine learning algorithm that uses decision trees during training and 
from sklearn.ensemble import RandomForestClassifier

#n_estimators are the number of trees in the forest, 100 is default value
#random_state is 1 for true and 0 for false, to initiate the model here, it is 1 i.e true
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)


train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       4 #n_estimators are the number of trees in the forest, 100 is default value
#       5 #random_state is 1 for true and 0 for false, to initiate the model here, it is 1 i.e true
#       6 model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
# ----> 9 train = sp500.iloc[:-100]
#      10 test = sp500.iloc[-100:]
#      12 predictors = ["Close", "Volume", "Open", "High", "Low"]
#
# NameError: name 'sp500' is not defined

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.0

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 1999-11-22 05:00:00+00:00       0            0
# 1999-11-23 05:00:00+00:00       1            0
# 1999-11-24 05:00:00+00:00       0            0
# 1999-11-26 05:00:00+00:00       0            0
# 1999-11-29 05:00:00+00:00       0            0
# ...                           ...          ...
# 2024-08-26 04:00:00+00:00       1            0
# 2024-08-27 04:00:00+00:00       0            0
# 2024-08-28 04:00:00+00:00       0            0
# 2024-08-29 04:00:00+00:00       1            0
# 2024-08-30 04:00:00+00:00       0            0
#
# [6233 rows x 2 columns]

# %%
predictions["Predictions"].value_counts()
# Out:
# 0    3337
# 1    2401
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.534777176176593

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.536075
# 0    0.463925
# Name: Target, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()
    
    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns != "Tomorrow"])

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2022-09-06  3930.889893  3942.550049  3886.750000  3908.189941  2209800080
# 2022-09-07  3909.429932  3987.889893  3906.030029  3979.870117           0
# 2022-09-08  3959.939941  4010.500000  3944.810059  4006.179932           0
# 2022-09-09  4022.939941  4076.810059  4022.939941  4067.360107           0
# 2022-09-12  4083.669922  4119.279785  4083.669922  4107.279785  1602969000
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.6] = 1
    preds[preds <.6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    3933
# 1.0     805
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5701863354037268

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.546855
# 0    0.453145
# Name: Target, dtype: float64

# %%
predictions
# Out:
#             Target  Predictions
# Date
# 2003-11-14       0          0.0
# 2003-11-17       0          1.0
# 2003-11-18       1          1.0
# 2003-11-19       0          0.0
# 2003-11-20       1          1.0
# ...            ...          ...
# 2022-09-06       1          0.0
# 2022-09-07       1          0.0
# 2022-09-08       1          0.0
# 2022-09-09       1          0.0
# 2022-09-12       0          0.0
#
# [4738 rows x 2 columns]
